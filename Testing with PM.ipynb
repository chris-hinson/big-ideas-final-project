# %% [markdown]
# ## Testing Air Quality (Namely PM)

# %%
## testing pm10

import pandas as pd
data = pd.read_csv('air quality data.csv')
sortedData=data.sort_values(by=['pm10','pm10b'])
sortedData.head(25)
# Out:
# /ihome/crc/install/python/miniconda3-3.7/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (4,8,10,14,16,18,20,22,28,30,32,34,36,38,40,42,44,46,48,50,56,58,60,62,64) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                          site             datetime stat  bcstat bcstat_txt  \
# 18239                 Lincoln  2017-09-23T00:00:00  Min     NaN        NaN
# 41574              Flag Plaza  2017-09-23T00:00:00  Min     NaN        NaN
# 13286                 Lincoln  2016-07-05T00:00:00  Min     NaN        NaN
# 21224                 Lincoln  2016-11-07T00:00:00  Min     NaN        NaN
# 111525             Flag Plaza  2019-07-22T00:00:00  Min     NaN        NaN
# 20709               Liberty 2  2016-10-07T00:00:00  Min     NaN        NaN
# 60675              Flag Plaza  2018-06-24T00:00:00  Min     NaN        NaN
# ...

# %%
##testing pm25

import pandas as pd
data = pd.read_csv('air quality data.csv')
sortedData=data.sort_values(by=['pm25','pm25b'])
sortedData.head(25)
# Out:
# /ihome/crc/install/python/miniconda3-3.7/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (4,8,10,14,16,18,20,22,28,30,32,34,36,38,40,42,44,46,48,50,56,58,60,62,64) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#              site             datetime stat  bcstat bcstat_txt  bp  bp_txt  \
# 106359    Lincoln  2019-05-21T00:00:00  Min     NaN        NaN NaN     NaN
# 2453      Lincoln  2016-02-16T00:00:00  Min     NaN        NaN NaN     NaN
# 4340      Lincoln  2016-03-18T00:00:00  Min     NaN        NaN NaN     NaN
# 5146    Liberty 2  2016-03-18T00:00:00  Min     NaN        NaN NaN     NaN
# 12778   Liberty 2  2016-06-28T00:00:00  Min     NaN        NaN NaN     NaN
# 12789   Liberty 2  2016-06-27T00:00:00  Min     NaN        NaN NaN     NaN
# 18618     Lincoln  2016-10-11T00:00:00  Min     NaN        NaN NaN     NaN
# ...
